# %%
import pandas as pd
df = pd.read_csv(C:\Users\fbass\OneDrive - IMAM ABDULRAHMAN BIN FAISAL UNIVERSITY\Desktop\daily_gym_attendance_workout_data.csv')


print(f"Dataset Shape: {df.shape}")
df.head()
df.info()
# Out:
#   Cell In[2], line 2
#     df = pd.read_csv('C:\Users\fbass\OneDrive - IMAM ABDULRAHMAN BIN FAISAL UNIVERSITY\Desktop\daily_gym_attendance_workout_data.csv')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
