# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\fbass\OneDrive - IMAM ABDULRAHMAN BIN FAISAL UNIVERSITY\Desktop\daily_gym_attendance_workout_data.csv')


print(f"Dataset Shape: {df.shape}")
df.head()
df.info()
